# %% [markdown]
# <a href="https://colab.research.google.com/github/raykiarie123-alt/CORD_19-App/blob/main/Salary_Prediction_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("abhishek14398/salary-dataset-simple-linear-regression")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 457/457 [00:00<00:00, 679kB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/abhishek14398/salary-dataset-simple-linear-regression/versions/1

# %%
#import libraries
import numpy as np
import pandas as pd
#for visualiation
import matplotlib.pyplot as plt
#for graphs
import seaborn as sns

# %%
#step 3: Read file
#copy the path
d1=pd.read_csv("/content/sample_data/Salary_dataset.csv")
d1.head(10)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0
# 5           5              3.0  56643.0
# 6           6              3.1  60151.0
# 7           7              3.3  54446.0
# 8           8              3.3  64446.0
# 9           9              3.8  57190.0

# %%
#to get a discrete information of your dataset
d1.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
###step 4: define the table

x=d1['YearsExperience']
y=d1['Salary']
plt.plot(x,y,'o')
plt.title('YearsExperience vs Salary')

plt.xlabel('YearsExperience')

plt.ylabel('Salary')

plt.show()
# Out:
#   File "/tmp/ipython-input-1534385914.py", line 3
#     y=d1['Salary]
#          ^
# SyntaxError: unterminated string literal (detected at line 3)
